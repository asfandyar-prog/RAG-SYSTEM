# %% [markdown]
# ## Data Ingestion

# %% [markdown]
#  LangChain Document Loader

# %%
from  langchain_core.documents import Document

# %%
from langchain_core.documents import Document

doc =Document(
    page_content="this is the official page content.",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)

print(doc)
# Out:
# page_content='this is the official page content.' metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}

# %%
## create a simple txt file

import os 
os.makedirs("../updatedgenerativeai/text_files",exist_ok=True)

# %%
sample_text = {
    "../updatedgenerativeai/text_files/python.txt":"""python is a high level interpreted programming language
    key Feature of python:
    1. Easy to learn and use
    2. Large standard library
    3. Platform independent
    4. Open source
    5. Large community
    6. Dynamic typing
    7. Automatic memory management
    8. Object oriented
    9. Interpreted
    10. High level
    """
}

# %%
for filepath,content  in sample_text.items():
    with open(filepath,"w",encoding="utf-8") as f:
        f.write(content)
    print(f"Created {filepath}")
# Out:
# Created ../updatedgenerativeai/text_files/python.txt

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../updatedgenerativeai/text_files/python.txt")
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': '../updatedgenerativeai/text_files/python.txt'}, page_content='python is a high level interpreted programming language\n    key Feature of python:\n    1. Easy to learn and use\n    2. Large standard library\n    3. Platform independent\n    4. Open source\n    5. Large community\n    6. Dynamic typing\n    7. Automatic memory management\n    8. Object oriented\n    9. Interpreted\n    10. High level\n    ')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader("../updatedgenerativeai/text_files", glob="*.txt",loader_cls=TextLoader,show_progress=True)
dir_docs = loader.load()
dir_docs
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 634.83it/s]
# [Document(metadata={'source': '..\\updatedgenerativeai\\text_files\\python.txt'}, page_content='python is a high level interpreted programming language\n    key Feature of python:\n    1. Easy to learn and use\n    2. Large standard library\n    3. Platform independent\n    4. Open source\n    5. Large community\n    6. Dynamic typing\n    7. Automatic memory management\n    8. Object oriented\n    9. Interpreted\n    10. High level\n    ')]

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
loader = DirectoryLoader("../updatedgenerativeai/pdf",
glob="**/*.pdf",
loader_cls=PyMuPDFLoader,
show_progress=True)
docs = loader.load()
docs
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  6.48it/s]
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-05T22:43:23+00:00', 'source': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Cover_Letter_TrustBridge.pdf', 'file_path': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Cover_Letter_TrustBridge.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-05T22:43:23+00:00', 'trapped': '', 'modDate': "D:20260205224323+00'00'", 'creationDate': "D:20260205224323+00'00'", 'page': 0}, page_content='Cover Letter\nName: Asfand Yar\nNeptun code: VL4F3Q\nEntrepreneurship attracts me because it enables turning innovative ideas into practical solutions\nthat address real societal challenges, such as building public trust in sustainable energy\ntechnologies. As a Computer Science student with a strong interest in artificial intelligence and its\napplication to complex physical systems, I am especially motivated by opportunities where\ntechnology can help organizations communicate complex processes in a clear and responsible\nway. This is particularly relevant in fields such as nuclear energy, which are vital for the future yet\noften face challenges in transparent public engagement.\nThis path is suitable for me because of my hands-on experience in initiative, teaching, and\ncollaborative technical work. I initiated and help deliver an introductory quantum computing course\nat the University of Debrecen using Qiskit, which has strengthened my ability to explain complex\ntechnical topics clearly to diverse audiences. As co-lead of the Google Developer Student Club and\na part-time Network/Technical Support Engineer at BMW Debrecen, I have gained experience in\nleading small teams, managing deadlines, learning new tools quickly, and applying technical\nknowledge in real-world environments. These experiences have developed my problem-solving,\ncommunication, and adaptability—key skills for fast-paced, team-based innovation projects.\nIn my view, the most important skills for a successful entrepreneur or key business professional\ninclude strong problem-solving combined with user-focused thinking, adaptability to new challenges\nand technologies, clear communication between experts and non-experts, effective teamwork in\ndiverse groups, and disciplined time management with a commitment to delivering results. While\ntechnical expertise is essential, understanding stakeholder needs, collaborating under constraints,\nand iterating solutions based on feedback are critical for achieving sustainable impact.\nThe MÜZLI Scholarship Programme is an ideal fit for me because it emphasizes exactly these\nelements. I am motivated to work actively in a small assigned team of new collaborators, in an\ninternational and English-speaking environment, while maintaining high attendance and reliability\nthroughout the mentoring process. I am prepared to prioritize consultations (80%+ attendance),\nmanage schedule conflicts flexibly, and deliver concrete outputs under mentor guidance.\nIn the nuclear revitalization block, I would contribute my AI and technical background to help\nprototype TrustBridge, an AI-powered, no-code simulator designed to support nuclear safety\ncommunication and public engagement. I would support the development of realistic safety\nscenarios grounded in physical principles, assist in translating safety logic into accessible\nexplanations, and help coordinate team tasks to ensure timely delivery. The Paks site visit and\ninteractions with international industry leaders would be particularly valuable for user research and\nvalidation, helping ensure that the tool reflects real communication needs within nuclear\norganizations.\nParticipating in the programme would allow me to further develop my entrepreneurial mindset\nthrough hands-on teamwork, time pressure, and mentor feedback, while contributing meaningfully\nt ...
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-05T23:22:13+00:00', 'source': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Final_Nuclear_Idea_Presentation.pdf', 'file_path': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Final_Nuclear_Idea_Presentation.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-05T23:22:13+00:00', 'trapped': '', 'modDate': "D:20260205232213+00'00'", 'creationDate': "D:20260205232213+00'00'", 'page': 0}, page_content='Idea Presentation\nName: Asfand Yar\nNeptun code: VL4F3Q\nThe long-term success and societal acceptance of nuclear energy depend not only on technological\nsafety, but also on how effectively nuclear organizations communicate their safety practices to\nstakeholders. Nuclear power plants operate under strict regulations and advanced safety systems;\nhowever, many organizations lack modern, interactive tools to explain how safety-related decisions\nare made in everyday operation. This communication gap can create uncertainty among local\ncommunities, students, policymakers, and the broader public, even in regions where overall support\nfor nuclear energy is relatively high.\nTraditional communication methods, such as static presentations or technical reports, often fail to\nconvey the dynamic and decision-based nature of nuclear safety. As a result, nuclear organizations\nface a strategic challenge: while their operational safety is robust, their ability to transparently\ncommunicate this safety in an engaging and understandable way is limited. This bottleneck can\nreduce trust, increase hesitation, and complicate public engagement and project support,\nparticularly among younger generations who lack direct exposure to real nuclear operations.\nTo address this challenge, the proposed project introduces TrustBridge, an AI-powered, no-code\nsimulator designed to make nuclear safety decision-making more transparent, understandable, and\nrelatable. TrustBridge is conceived as a tool that nuclear organizations can use to communicate\nsafety logic to a broad audience, including secondary school students, university students, and the\ngeneral public. Using the platform, interactive safety scenarios can be created that reflect specific\nreactor technologies, operational philosophies, and real-world contexts without requiring\nprogramming skills.\nThrough the simulator, users can explore simplified yet realistic operational scenarios, such as\nnormal plant operation, maintenance planning, and early stress or anomaly situations. Users\ninteract with these scenarios by making basic decisions and observing outcomes, while an\nintegrated AI explanation system clarifies why certain actions are chosen from a safety perspective.\nThe explanations are generated in clear, non-technical language and are grounded in fundamental\nphysical principles, including heat transfer, reactor cooling, and the concept of layered safety\nsystems. This approach helps demonstrate the preventive and conservative logic that defines\nnuclear safety culture.\nFrom a technical standpoint, TrustBridge can be implemented using no-code development tools\nsuch as Bubble or Adalo, combined with an AI language model API for generating context-aware\nexplanations. The interface relies on visual indicators, decision trees, and scenario-based flows\ninstead of mathematical detail, ensuring accessibility for non-expert audiences while remaining\nfeasible within the programme timeframe. The no-code architecture also allows the simulator to be\nreused in classrooms, outreach events, and public engagement activities.\nUniversity-level initiatives and innovation-focused programmes can play a key role in bridging the\ngap between the nuclear industry, education, and society by involving students directly in the\ndevelopment of such communication tools. Wit ...
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-05T23:22:13+00:00', 'source': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Final_Nuclear_Idea_Presentation.pdf', 'file_path': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Final_Nuclear_Idea_Presentation.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-05T23:22:13+00:00', 'trapped': '', 'modDate': "D:20260205232213+00'00'", 'creationDate': "D:20260205232213+00'00'", 'page': 1}, page_content='reflects real operational practices.\nBy the end of the programme, the project aims to deliver a functional prototype of TrustBridge\nfeaturing at least one VVER-based safety communication scenario. This outcome demonstrates\nhow university-led innovation, combined with industry collaboration, can contribute to making\nnuclear energy more understandable, transparent, and relatable, while strengthening the\nconnection between education, industry, and society.\nIn conclusion, TrustBridge supports the responsible revitalization of the nuclear industry by\ntransforming complex safety decision-making into an interactive learning experience. By combining\ndigital tools, university-based innovation, and industry input, the project contributes to informed\npublic dialogue and increased trust in nuclear energy.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-05T22:15:52+00:00', 'source': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Idea_Presentation.pdf', 'file_path': '..\\updatedgenerativeai\\pdf\\Asfand_Yar_MUZLI_Idea_Presentation.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-05T22:15:52+00:00', 'trapped': '', 'modDate': "D:20260205221552+00'00'", 'creationDate': "D:20260205221552+00'00'", 'page': 0}, page_content='Idea Presentation\nName: Asfand Yar\nNeptun code: VL4F3Q\nTitle: AI-Powered Nuclear Safety Decision Simulator for Education and Public Trust\nThe long-term sustainability of the nuclear industry depends not only on technological excellence,\nbut also on public trust and understanding. While nuclear energy enjoys relatively strong support in\nHungary and across Europe, many people—especially younger generations—still feel uncertain\nabout nuclear safety because they lack insight into how safety-related decisions are actually made.\nNuclear safety is often perceived as highly complex and inaccessible, which creates psychological\ndistance between the industry and society.\nAlthough recent surveys indicate that a majority of Hungarians consider nuclear energy decisive in\nthe future energy mix, hesitation persists due to misconceptions surrounding safety, risk\nmanagement, and emergency prevention. This gap is particularly evident among students, who\nrarely encounter nuclear topics beyond theoretical explanations and have little opportunity to\nexplore real-world operational logic. As a result, support for nuclear energy often exists without a\ndeeper, trust-based understanding.\nTo address this challenge, the proposed project focuses on making nuclear safety decision-making\ntransparent and understandable through an interactive, AI-powered educational tool. The core idea\nis to develop a no-code Nuclear Safety Decision Simulator that allows users to explore simplified\nbut realistic operational scenarios inspired by real nuclear power plant practices. Instead of\npassively consuming information, users actively participate in decision-making processes and\nobserve how different choices affect safety outcomes.\nThe simulator presents users with scenarios such as normal operation, maintenance planning, and\nearly warning situations. In each case, users choose between decision options and receive\nimmediate feedback supported by an AI-based explanation system. The AI explains why certain\ndecisions are safer, using clear language and fundamental physical principles such as heat\ntransfer, reactor cooling, and layered safety systems. This approach highlights the preventive and\nconservative logic that defines nuclear safety culture.\nFrom a technical perspective, the platform can be implemented using no-code development tools\nsuch as Bubble or Adalo, combined with an AI language model API to generate context-aware\nexplanations. Visual indicators, decision trees, and scenario-based storytelling will be used instead\nof mathematical complexity, ensuring accessibility for non-technical users and feasibility within the\nprogramme timeframe.\nThe project has strong relevance to the Hungarian nuclear context. Scenario logic can be inspired\nby VVER reactor principles used at the Paks Nuclear Power Plant and refined based on insights\ngained during the planned site visit and mentor consultations. The platform can also incorporate\nshort pre- and post-use surveys to evaluate changes in user understanding and perceived trust,\nproviding qualitative feedback on impact.\nThis idea aligns closely with my academic background in computer science, artificial intelligence,\nand physics-oriented thinking. By combining AI-based explanation with realistic safety logic, the\nproject demonstrates how advanced digital tools can support transparency, edu ...
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-05T18:01:34+00:00', 'source': '..\\updatedgenerativeai\\pdf\\MUZLI_Cover_Letter_Final.pdf', 'file_path': '..\\updatedgenerativeai\\pdf\\MUZLI_Cover_Letter_Final.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-05T18:01:34+00:00', 'trapped': '', 'modDate': "D:20260205180134+00'00'", 'creationDate': "D:20260205180134+00'00'", 'page': 0}, page_content='Cover Letter\nName: Sayor S M Sadman Sakib\nNeptun code: KAC25U\nEntrepreneurship attracts me because it allows me to transform ideas into real-world solutions that\ncreate meaningful impact. As a computer science student focusing on artificial intelligence, I am\nespecially interested in building technology-driven products that solve practical problems in\neducation, communication, and low-resource environments. Entrepreneurship gives me the\nopportunity to experiment, innovate, and take responsibility for the entire process, from idea\ngeneration to implementation and deployment.\nI believe entrepreneurship is a suitable path for me because of my strong technical background and\ninitiative-driven mindset. During my studies, I have worked on projects in AI, mobile applications,\nand cryptography, and I have also taken part in teaching and research activities. These\nexperiences strengthened my problem-solving, communication, and leadership skills. I am\ncomfortable learning new technologies quickly and applying them in practical situations, which is\nessential in fast-moving entrepreneurial environments.\nIn my opinion, the most important skills for a successful entrepreneur or key business professional\ninclude problem-solving ability, adaptability, communication, teamwork, and strategic thinking.\nTechnical knowledge is important, but understanding user needs, managing time effectively, and\ncollaborating with diverse teams are equally critical. A growth mindset, resilience, and ethical\ndecision-making are also essential for building sustainable and responsible businesses.')]
